# %% [markdown]
# # Exploratory data analysis
#     This kernel is to get familiar with the features and their relation, look for possible feature engineering
#     To realize the meaning of features, please read the following website
# * https://www.kaggle.com/c/data-science-bowl-2019/data
# * https://www.kaggle.com/c/data-science-bowl-2019/discussion/117019#latest-680222
#
# ## kaggle example
# * https://www.kaggle.com/c/data-science-bowl-2019/notebooks?sortBy=commentCount&group=everyone&search=EDA&page=1&pageSize=20&competitionId=16531
#
# ### Question:
# * still not figure out how even_id relate to other features
# * prediction of test is for last assessment session??
#
# ### Try new ploting tools:
# * [plotly](https://plot.ly/python/)
# * [seaborn](https://seaborn.pydata.org/index.html)

# %%
import numpy as np
import pandas as pd
from IPython.display import display

import matplotlib.pyplot as plt
# %matplotlib inline

from utils import kaggle_util

# %%
# https://www.kaggle.com/robikscube/2019-data-science-bowl-an-introduction

import seaborn as sns
sns.set_style("whitegrid")
my_pal = sns.color_palette(n_colors=10)

# %%
# %%time

# read data
train, test, train_labels, specs, sample_submission = kaggle_util.read_data()
train2, test2, train_labels2 = train.copy(), test.copy(), train_labels.copy()

# get usefull dict with maping encode, we implement "label encoding" on category features
train2, test2, train_labels2, win_code, list_of_user_activities, list_of_event_code,\
activities_labels, assess_titles, list_of_event_id, all_title_event_code = kaggle_util.encode_title(train2, test2, train_labels2)
# Out:
# Reading train.csv file....
# Training.csv file have 11341042 rows and 11 columns
# Reading test.csv file....
# Test.csv file have 1156414 rows and 11 columns
# Reading train_labels.csv file....
# Train_labels.csv file have 17690 rows and 7 columns
# Reading specs.csv file....
# Specs.csv file have 386 rows and 3 columns
# Reading sample_submission.csv file....
# Sample_submission.csv file have 1000 rows and 2 columns
# CPU times: user 1min 4s, sys: 7.38 s, total: 1min 11s
# Wall time: 1min 11s

# %%
# no missing value
# display(train.isnull().sum())
# display(test.isnull().sum())
# display(train_labels.isnull().sum())
# display(specs.isnull().sum())

# %%
# a glimps in these files

print(train.dtypes)
display(train)
display(specs)
display(train_labels)
# Out:
# event_id           object
# game_session       object
# timestamp          object
# event_data         object
# installation_id    object
# event_count         int64
# event_code          int64
# game_time           int64
# title              object
# type               object
# world              object
# dtype: object
#           event_id      game_session                 timestamp  \
# 0         27253bdc  45bb1e1b6b50c07b  2019-09-06T17:53:46.937Z
# 1         27253bdc  17eeb7f223665f53  2019-09-06T17:54:17.519Z
# 2         77261ab5  0848ef14a8dc6892  2019-09-06T17:54:56.302Z
# 3         b2dba42b  0848ef14a8dc6892  2019-09-06T17:54:56.387Z
# 4         1bb5fbdb  0848ef14a8dc6892  2019-09-06T17:55:03.253Z
# ...            ...               ...                       ...
# 11341037  ab3136ba  c09b94eebfdf50a6  2019-10-10T15:11:15.584Z
# 11341038  27253bdc  6ad8ab25003ef1b0  2019-10-10T15:12:17.364Z
# 11341039  27253bdc  71904dca23b982c6  2019-10-10T15:13:04.713Z
# 11341040  27253bdc  2267b18f069e875a  2019-10-10T15:13:54.545Z
# 11341041  27253bdc  f31950f549d7c242  2019-10-10T15:15:12.483Z
#
#                                                  event_data installation_id  \
# 0                    {"event_code": 2000, "event_count": 1}        0001e90f
# 1                    {"event_code": 2000, "event_count": 1}        0001e90f
# 2         {"version":"1.0","event_count":1,"game_time":0...        0001e90f
# 3         {"description":"Let's build a sandcastle! Firs...        0001e90f
# 4         {"description":"Let's build a sandcastle! Firs...        0001e90f
# ...                                                     ...             ...
# 11341037  {"description":"Tap another dinosaur.","identi...        fffc0583
# 11341038             {"event_code": 2000, "event_count": 1}        fffc0583
# 11341039             {"event_code": 2000, "event_count": 1}        fffc0583
# 11341040             {"event_code": 2000, "event_count": 1}        fffc0583
# 11341041             {"event_code": 2000, "event_count": 1}        fffc0583
#
#           event_count  event_code  game_time                          title  \
# 0                   1        2000          0        Welcome to Lost Lagoon!
# 1                   1        2000          0           Magma Peak - Level 1
# 2                   1        2000          0  Sandcastle Builder (Activity)
# 3                   2        3010         53  Sandcastle Builder (Activity)
# 4                   3        3110       6972  Sandcastle Builder (Activity)
# ...               ...         ...        ...                            ...
# 11341037           66        3110     118615                      Dino Dive
# 11341038            1        2000          0        Crystal Caves - Level 2
# 11341039            1        2000          0        Crystal Caves - Level 3
# 11341040            1        2000          0        Crystal Caves - Level 3
# 11341041            1        2000          0        Tree Top City - Level 2
#
#               type         world
# 0             Clip          NONE
# 1             Clip     MAGMAPEAK
# 2         Activity     MAGMAPEAK
# 3         Activity     MAGMAPEAK
# 4         Activity     MAGMAPEAK
# ...            ...           ...
# 11341037      Game     MAGMAPEAK
# 11341038      Clip  CRYSTALCAVES
# 11341039      Clip  CRYSTALCAVES
# 11341040      Clip  CRYSTALCAVES
# 11341041      Clip   TREETOPCITY
#
# [11341042 rows x 11 columns]
#      event_id                                               info  \
# 0    2b9272f4  The end of system-initiated feedback (Correct)...
# 1    df4fe8b6  The end of system-initiated feedback (Incorrec...
# 2    3babcb9b  The end of system-initiated instruction event ...
# 3    7f0836bf  The end of system-initiated instruction event ...
# 4    ab3136ba  The end of system-initiated instruction event ...
# ..        ...                                                ...
# 381  29f54413  The start round event is triggered at the star...
# 382  06372577  The start tutorial event is triggered at the s...
# 383  2a444e03  This event occurs when the player picks up a w...
# 384  9e6b7fb5  This event occurs when the player clicks on th...
# 385  d3640339  This event occurs when the player clicks on th...
#
#                                                   args
# 0    [{"name":"game_time","type":"int","info":"mill...
# 1    [{"name":"game_time","type":"int","info":"mill...
# 2    [{"name":"game_time","type":"int","info":"mill...
# 3    [{"name":"game_time","type":"int","info":"mill...
# 4    [{"name":"game_time","type":"int","info":"mill...
# ..                                                 ...
# 381  [{"name":"game_time","type":"int","info":"mill...
# 382  [{"name":"game_time","type":"int","info":"mill...
# 383  [{"name":"game_time","type":"int","info":"mill...
# 384  [{"name":"game_time","type":"int","info":"mill...
# 385  [{"name":"game_time","type":"int","info":"mill...
#
# [386 rows x 3 columns]
#            game_session installation_id                         title  \
# 0      6bdf9623adc94d89        0006a69f  Mushroom Sorter (Assessment)
# 1      77b8ee947eb84b4e        0006a69f    Bird Measurer (Assessment)
# 2      901acc108f55a5a1        0006a69f  Mushroom Sorter (Assessment)
# 3      9501794defd84e4d        0006a69f  Mushroom Sorter (Assessment)
# 4      a9ef3ecb3d1acc6a        0006a69f    Bird Measurer (Assessment)
# ...                 ...             ...                           ...
# 17685  c996482b11d149dd        ffc90c32    Bird Measurer (Assessment)
# 17686  b05a02b52d5c1f4c        ffd2871d  Cauldron Filler (Assessment)
# 17687  5448d652309a6324        ffeb0b1b  Cauldron Filler (Assessment)
# 17688  a6885ab824fbc32c        ffeb0b1b  Mushroom Sorter (Assessment)
# 17689  dadd1a4d8ac68ab0        ffeb0b1b  Cauldron Filler (Assessment)
#
#        num_correct  num_incorrect  accuracy  accuracy_group
# 0                1              0  1.000000               3
# 1                0             11  0.000000               0
# 2                1              0  1.000000               3
# 3                1              1  0.500000               2
# 4                1              0  1.000000               3
# ...            ...            ...       ...             ...
# 17685            1              0  1.000000               3
# 17686            1              0  1.000000               3
# 17687            1              2  0.333333               1
# 17688            0              1  0.000000               0
# 17689            1              2  0.333333               1
#
# [17690 rows x 7 columns]

# %%
train[(train['installation_id']=='0006a69f')]
train[(train['installation_id']=='0006a69f') & (train['game_session']=='2b9d5af79bcdb79f')]
# Out:
#       event_id      game_session                 timestamp  \
# 1540  77261ab5  2b9d5af79bcdb79f  2019-08-06T04:58:14.538Z
# 1541  b2dba42b  2b9d5af79bcdb79f  2019-08-06T04:58:14.615Z
# 1542  1325467d  2b9d5af79bcdb79f  2019-08-06T04:58:16.680Z
# 1543  1325467d  2b9d5af79bcdb79f  2019-08-06T04:58:18.474Z
# 1544  1325467d  2b9d5af79bcdb79f  2019-08-06T04:58:19.365Z
# ...        ...               ...                       ...
# 1637  37937459  2b9d5af79bcdb79f  2019-08-06T04:59:42.203Z
# 1638  b2dba42b  2b9d5af79bcdb79f  2019-08-06T04:59:42.203Z
# 1639  1bb5fbdb  2b9d5af79bcdb79f  2019-08-06T04:59:44.270Z
# 1640  37937459  2b9d5af79bcdb79f  2019-08-06T04:59:44.311Z
# 1641  b2dba42b  2b9d5af79bcdb79f  2019-08-06T04:59:44.312Z
#
#                                              event_data installation_id  \
# 1540  {"version":"1.0","event_count":1,"game_time":0...        0006a69f
# 1541  {"description":"Let's build a sandcastle! Firs...        0006a69f
# 1542  {"coordinates":{"x":273,"y":650,"stage_width":...        0006a69f
# 1543  {"coordinates":{"x":863,"y":237,"stage_width":...        0006a69f
# 1544  {"coordinates":{"x":817,"y":617,"stage_width":...        0006a69f
# ...                                                 ...             ...
# 1637  {"castles_placed":[{"size":3,"position":{"x":5...        0006a69f
# 1638  {"description":"Drag the shovel to the molds t...        0006a69f
# 1639  {"description":"Drag the shovel to the molds t...        0006a69f
# 1640  {"castles_placed":[{"size":3,"position":{"x":5...        0006a69f
# 1641  {"description":"Drag the shovel to the molds t...        0006a69f
#
#       event_count  event_code  game_time                          title  \
# 1540            1        2000          0  Sandcastle Builder (Activity)
# 1541            2        3010         29  Sandcastle Builder (Activity)
# 1542            3        4070       2137  Sandcastle Builder (Activity)
# 1543            4        4070       3937  Sandcastle Builder (Activity)
# 1544            5        4070       4820  Sandcastle Builder (Activity)
# ...           ...         ...        ...                            ...
# 1637           98        4090      87658  Sandcastle Builder (Activity)
# 1638           99        3010      87658  Sandcastle Builder (Activity)
# 1639          100        3110      89733  Sandcastle Builder (Activity)
# 1640          101        4090      89767  Sandcastle Builder (Activity)
# 1641          102        3010      89767  Sandcastle Builder (Activity)
#
#           type      world
# 1540  Activity  MAGMAPEAK
# 1541  Activity  MAGMAPEAK
# 1542  Activity  MAGMAPEAK
# 1543  Activity  MAGMAPEAK
# 1544  Activity  MAGMAPEAK
# ...        ...        ...
# 1637  Activity  MAGMAPEAK
# 1638  Activity  MAGMAPEAK
# 1639  Activity  MAGMAPEAK
# 1640  Activity  MAGMAPEAK
# 1641  Activity  MAGMAPEAK
#
# [102 rows x 11 columns]

# %%
def describe_category(s: pd.Series):
    print('{} kinds of category'.format(s.nunique()))
    
    # plot histgram
    s.hist(bins=s.nunique())
    plt.show()
    plt.clf()

# %%
describe_category(train.event_code)
describe_category(train.title)
describe_category(train.type)
describe_category(train.world)
# Out:
# 42 kinds of category
# 44 kinds of category
# 4 kinds of category
# 4 kinds of category

# %%
def describe_category2(s: pd.Series):
    print('{} kinds of category'.format(s.nunique()))
    # how many s in one category, numeric version of histgram
    print(s.value_counts().value_counts())
    
    s.value_counts().hist(bins=100)
    plt.show()
    plt.clf()

# %%
## most game_session has less than 500 rows
describe_category2(train.game_session)

## most installation_id has less than 5 rows
describe_category2(train.installation_id)
# Out:
# 303319 kinds of category
# 1       185970
# 3         2375
# 35        1434
# 2         1335
# 30        1297
#          ...
# 1233         1
# 1333         1
# 1077         1
# 886          1
# 767          1
# Name: game_session, Length: 958, dtype: int64
# 17000 kinds of category
# 2       1185
# 1       1179
# 3        776
# 4        463
# 5        263
#         ...
# 1448       1
# 1464       1
# 3513       1
# 1496       1
# 1607       1
# Name: installation_id, Length: 2912, dtype: int64

# %% [markdown]
# ## Compare distribution between train and test

# %%
def count_nunique(df: pd.DataFrame):
    for c in df.columns:
        if c!= 'timestamp' or c!= 'event_data':
            print(c,df[c].nunique())

# %%
print(train.shape)
print(test.shape)

print("\nTraining data unique value count")
print(count_nunique(train[['event_id','game_session','installation_id','event_count']]))
  
print("\nTesting data unique value count")
print(count_nunique(test[['event_id','game_session','installation_id','event_count']]))
# Out:
# (11341042, 11)
# (1156414, 11)
#
# Training data unique value count
# event_id 384
# game_session 303319
# installation_id 17000
# event_count 3368
# None
#
# Testing data unique value count
# event_id 365
# game_session 28445
# installation_id 1000
# event_count 4456
# None

# %%
## check if train_labels contain all assessment game session in train
train_ass_sessoin = train[train['type']=='Assessment']['game_session'].unique()
train_label_ass_session = train_labels.game_session.values
print(train_ass_sessoin.shape)
print(train_label_ass_session.shape)

not_in_train_label_ass_session = []
for s in train_ass_sessoin:
    if s not in train_label_ass_session:
        not_in_train_label_ass_session.append(s)
        
print(len(not_in_train_label_ass_session))
no_label_ass_session = train[train['game_session'].isin(not_in_train_label_ass_session)]
# Out:
# (21239,)
# (17690,)
# 3549

# %%
# valid event_code of 'Bird Measurer (Assessment)' is 4110
# so every assessment with valid attempts is included in train_label
display(no_label_ass_session[no_label_ass_session['event_code']==4100])
display(no_label_ass_session[no_label_ass_session['event_code']==4110])
# Out:
#          event_id      game_session                 timestamp  \
# 5647267  070a5291  e3436dd3c423a14f  2019-08-21T13:35:44.250Z
# 5647287  070a5291  e3436dd3c423a14f  2019-08-21T13:36:36.161Z
# 9239261  070a5291  d22a979eaed378ed  2019-10-01T14:46:22.861Z
#
#                                                 event_data installation_id  \
# 5647267  {"correct":false,"hats":[5,4,8],"event_count":...        7d351303
# 5647287  {"correct":true,"hats":[4,8,5],"event_count":8...        7d351303
# 9239261  {"correct":true,"hats":[4,8,5],"event_count":2...        cf6792b9
#
#          event_count  event_code  game_time                       title  \
# 5647267           67        4100      97693  Bird Measurer (Assessment)
# 5647287           87        4100     149598  Bird Measurer (Assessment)
# 9239261           29        4100      35889  Bird Measurer (Assessment)
#
#                type        world
# 5647267  Assessment  TREETOPCITY
# 5647287  Assessment  TREETOPCITY
# 9239261  Assessment  TREETOPCITY
# Empty DataFrame
# Columns: [event_id, game_session, timestamp, event_data, installation_id, event_count, event_code, game_time, title, type, world]
# Index: []

# %% [markdown]
# ## TODO
# Plot!!!!!!

# %%
## Timestamp analysis

## time stamp v.s. accuracy group, num
## user v.s. time stamp range

# %%
## Train2 analysis

# %% [markdown]
# ## Feature engineering
# * base on accumulate events(features)?
# * and then?

# %% [markdown]
# ## How to perform regression & optimize threshold?

# %% [markdown]
# ## Testing codes~

# %%
from collections import Counter
Counter(train[(train['installation_id']=='0006a69f') & (train['game_session']=='2b9d5af79bcdb79f')]['event_code'])
# Out:
# Counter({2000: 1,
#          3010: 20,
#          4070: 18,
#          3110: 19,
#          4030: 21,
#          4021: 14,
#          4020: 7,
#          4090: 2})
