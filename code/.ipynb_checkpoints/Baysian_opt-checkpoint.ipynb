# %%
import pandas as pd
import os
import numpy as np
from bayes_opt import BayesianOptimization
from sklearn.model_selection import train_test_split
from catboost import CatBoostRegressor, Pool
import lightgbm as lgb
import xgboost as xgb

import gc
from numba import jit

random_seed = 33

train_file = 'train_0102_filter.csv'    
write_path = './BayesOpt_result/'

# model_type = 'catboost'
model_type = 'lgb'
# model_type = 'xgb'

if model_type == 'catboost':
    record_file = 'catboost_result.txt'
elif model_type == 'lgb':
    record_file = 'lgb_result.txt'
elif model_type == 'xgb':
    record_file = 'xgb_result.txt'
else:
    pass

iteration = 150
init_it = 50
category_list = []

# %%
@jit
def qwk(a1, a2):
    """
    Source: https://www.kaggle.com/c/data-science-bowl-2019/discussion/114133#latest-660168

    :param a1:
    :param a2:
    :param max_rat:
    :return:
    """
    max_rat = 3
    a1 = np.asarray(a1, dtype=int)
    a2 = np.asarray(a2, dtype=int)

    hist1 = np.zeros((max_rat + 1, ))
    hist2 = np.zeros((max_rat + 1, ))

    o = 0
    for k in range(a1.shape[0]):
        i, j = a1[k], a2[k]
        hist1[i] += 1
        hist2[j] += 1
        o +=  (i - j) * (i - j)

    e = 0
    for i in range(max_rat + 1):
        for j in range(max_rat + 1):
            e += hist1[i] * hist2[j] * (i - j) * (i - j)

    e = e / a1.shape[0]

    return 1 - o / e

def eval_qwk_lgb_regr(y_true, y_pred):
    """
    Fast cappa eval function for lgb.
    """
    y_pred[y_pred <= 1.12232214] = 0
    y_pred[np.where(np.logical_and(y_pred > 1.12232214, y_pred <= 1.73925866))] = 1
    y_pred[np.where(np.logical_and(y_pred > 1.73925866, y_pred <= 2.22506454))] = 2
    y_pred[y_pred > 2.22506454] = 3

    # y_pred = y_pred.reshape(len(np.unique(y_true)), -1).argmax(axis=0)

    return 'cappa', qwk(y_true, y_pred), True

# %%
train = pd.read_csv('../data/preprocess/'+train_file)
cols_to_drop = ['game_session', 'installation_id', 'timestamp', 'accuracy_group', 'timestampDate']
y = train['accuracy_group'].copy()
for c in cols_to_drop:
    if c in train.columns:
        train = train.drop(columns = c)
X = train

## 驗證集
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=random_seed, stratify=y)
     
categorical_features_indices = np.where(X_train.columns.isin(category_list))[0]
print(X_train.dtypes[categorical_features_indices])

## catboost 調參
## https://catboost.ai/docs/concepts/loss-functions-regression.html
param_cat={
    'loss_function':'RMSE', ##MAE
    'eval_metric':'RMSE',
    
    'iterations':14000,
    'random_seed':random_seed,
    'thread_count':5,
    'task_type':"GPU",
    'devices':'0:1',
#     'boosting_type':'Ordered',
    'learning_rate':0.03,
    'l2_leaf_reg':20,#20
    'depth':7,
    'bagging_temperature':0.3,
    'random_strength':10,
    # 'rsm':0.8,

    # 'fold_permutation_block':1,
    # 'feature_border_type':'MinEntropy',
    # 'boosting_type':'Ordered',
    # 'leaf_estimation_backtracking':'Armijo',
    
    'one_hot_max_size':200,
#     'grow_policy':'Lossguide',
#     'grow_policy':'Lossguide',
}
param_range_cat={
#     'depth':(5,16.9),
#     'max_leaves':(20,45),
    'depth':(5,12.9),
    'max_leaves':(31,31.5),
    'l2_leaf_reg':(1,100),
    'bagging_temperature':(0.01,5)  
}

## LGB調參
## https://lightgbm.readthedocs.io/en/latest/pythonapi/lightgbm.LGBMRegressor.html#lightgbm.LGBMRegressor
## https://lightgbm.readthedocs.io/en/latest/Parameters-Tuning.html

param_lgb = {'n_estimators':10000,
            'boosting_type': 'gbdt',
            'objective': 'regression',
            'metric': 'rmse',
            'subsample': 0.75,
            'subsample_freq': 1,
            'learning_rate': 0.04,
            'feature_fraction': 0.9,
            'max_depth': 15,
            'lambda_l1': 1,  
            'lambda_l2': 1,
            'verbose': 100,
            'early_stopping_rounds': 400, 'eval_metric': 'cappa'
            }

param_range_lgb={
    'max_depth': (5,16),
    'num_leaves': (15,100),
    'feature_fraction': (0.3,1),
    
    'subsample':(0.2,1),
    'subsample_freq':(1,3),
    'lambda_l1':(0.1,50),
    'lambda_l2':(0.1,50),
}


param_clf = {}
param_range = {}

if model_type == 'catboost':
    param_clf = param_cat
    param_range = param_range_cat
elif model_type == 'lgb':
    param_clf = param_lgb
    param_range = param_range_lgb
elif model_type == 'xgb':
    param_clf = param_lgb
    param_range = param_range_lgb
else:
    pass

def bys_train_catboost(depth,max_leaves,l2_leaf_reg,bagging_temperature):
    param_clf['depth']=int(depth)
    param_clf['max_leaves']=int(max_leaves)
    param_clf['l2_leaf_reg']=l2_leaf_reg
    param_clf['bagging_temperature']=bagging_temperature
    
    model = CatBoostRegressor(**param_clf)
    model.fit(X_train, y_train,
    cat_features=categorical_features_indices,    
    eval_set=(X_test, y_test),
    early_stopping_rounds=200,
    verbose=50) 
     
    score_max = model.get_best_score()['validation']['RMSE']
    
    print(int(depth),int(max_leaves),l2_leaf_reg,bagging_temperature)
    print(score_max)
    
    with open(write_path+record_file,'a') as f:
        print('depth',int(depth),file=f)
        print('max_leaves',int(max_leaves),file=f)
        print('l2_leaf_reg',l2_leaf_reg,file=f)
        print('bagging_temperature',bagging_temperature,file=f)
        print(score_max,file=f)
        print('',file=f)
    
    return -score_max

def bys_train_lgb(max_depth,num_leaves,feature_fraction,subsample,subsample_freq,lambda_l1,lambda_l2):
    param_clf['max_depth']=int(max_depth)
    param_clf['num_leaves']=int(num_leaves)
    param_clf['feature_fraction']=feature_fraction
    param_clf['subsample']=subsample
    param_clf['subsample_freq']=int(subsample_freq)
    param_clf['lambda_l1']=lambda_l1
    param_clf['lambda_l2']=lambda_l2
        
    model = lgb.LGBMRegressor(**param_clf)
    model.fit(X=X_train, y=y_train,
              eval_set=[(X_train, y_train),(X_test, y_test)], eval_metric=eval_qwk_lgb_regr,
              verbose=param_clf['verbose'], early_stopping_rounds=param_clf['early_stopping_rounds'],
              categorical_feature=categorical_features_indices)

    score_max = model.best_score_['valid_1']['rmse']
    
    print("parameter",int(max_depth),int(num_leaves),feature_fraction,subsample,int(subsample_freq),lambda_l1,lambda_l2)
    print("score",score_max)
    
    with open(write_path+record_file,'a') as f:
        print('max_depth',int(max_depth),file=f)
        print('num_leaves',int(num_leaves),file=f)
        print('feature_fraction',feature_fraction,file=f)
        print('subsample',subsample,file=f)
        print('subsample_freq',int(subsample_freq),file=f)
        print('lambda_l1',lambda_l1,file=f)
        print('lambda_l2',lambda_l2,file=f)
        print(score_max,file=f)
        print('',file=f)
    
    return -score_max

def main(write_path='./BayesOpt_result/',record_file='Bayes_result.txt',iteration=5,init_it=5):
    print(iteration)
    with open(write_path+record_file,'a') as f:
        print('\n{}'.format(train_file),file=f)
        
    if model_type == 'catboost':
        Bys_opt = BayesianOptimization(bys_train_catboost,param_range)#, acq="ucb", kappa=1) 
    elif model_type == 'lgb':
        Bys_opt = BayesianOptimization(bys_train_lgb,param_range)#, acq="ucb", kappa=1) 
    elif model_type == 'xgb':
        Bys_opt = BayesianOptimization(bys_train_lgb,param_range)#, acq="ucb", kappaand=1) 
    else:
        pass
    
    Bys_opt.maximize(n_iter=iteration, init_points=init_it)
    print(Bys_opt.max)
    
    with open(write_path+record_file,'a') as f:
        print('Max para',Bys_opt.max,file=f)

main(write_path=write_path, record_file=record_file, iteration=iteration,init_it=init_it)
# Out:
# Series([], dtype: object)
# 150
# |   iter    |  target   | featur... | lambda_l1 | lambda_l2 | max_depth | num_le... | subsample | subsam... |
# -------------------------------------------------------------------------------------------------------------
# /home/jupyter-shliu/.local/lib/python3.6/site-packages/lightgbm/engine.py:153: UserWarning: Found `early_stopping_rounds` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# /home/jupyter-shliu/.local/lib/python3.6/site-packages/lightgbm/basic.py:1236: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if self.categorical_feature == categorical_feature:
# /home/jupyter-shliu/.local/lib/python3.6/site-packages/lightgbm/basic.py:1242: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   elif categorical_feature == 'auto':
# /home/jupyter-shliu/.local/lib/python3.6/site-packages/lightgbm/basic.py:1247: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is []
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /home/jupyter-shliu/.local/lib/python3.6/site-packages/lightgbm/basic.py:285: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if categorical_feature == 'auto':  # use cat cols from DataFrame
# <ipython-input-2-8292d78451f9>:1: NumbaWarning:
# Compilation is falling back to object mode WITH looplifting enabled because Function "qwk" failed type inference due to: Invalid use of Function(<function asarray at 0x7f2e6c1b82f0>) with argument(s) of type(s): (array(float32, 1d, C), dtype=Function(<class 'int'>))
#  * parameterized
# In definition 0:
#     AttributeError: 'Function' object has no attribute 'dtype'
#     raised from /home/jupyter-shliu/.local/lib/python3.6/site-packages/numba/targets/arraymath.py:3845
# In definition 1:
#     AttributeError: 'Function' object has no attribute 'dtype'
#     raised from /home/jupyter-shliu/.local/lib/python3.6/site-packages/numba/targets/arraymath.py:3845
# This error is usually caused by passing an argument of a type that is unsupported by the named function.
# [1] During: resolving callee type: Function(<function asarray at 0x7f2e6c1b82f0>)
# [2] During: typing of call at <ipython-input-2-8292d78451f9> (12)
#
#
# File "<ipython-input-2-8292d78451f9>", line 12:
# def qwk(a1, a2):
#     <source elided>
#     max_rat = 3
#     a1 = np.asarray(a1, dtype=int)
#     ^
#
#   @jit
# <ipython-input-2-8292d78451f9>:1: NumbaWarning:
# Compilation is falling back to object mode WITHOUT looplifting enabled because Function "qwk" failed type inference due to: cannot determine Numba type of <class 'numba.dispatcher.LiftedLoop'>
#
# File "<ipython-input-2-8292d78451f9>", line 19:
# def qwk(a1, a2):
#     <source elided>
#     o = 0
#     for k in range(a1.shape[0]):
#     ^
#
#   @jit
# /home/jupyter-shliu/.local/lib/python3.6/site-packages/numba/object_mode_passes.py:178: NumbaWarning: Function "qwk" was compiled in object mode without forceobj=True, but has lifted loops.
#
# File "<ipython-input-2-8292d78451f9>", line 2:
# @jit
# def qwk(a1, a2):
# ^
#
#   state.func_ir.loc))
# /home/jupyter-shliu/.local/lib/python3.6/site-packages/numba/object_mode_passes.py:187: NumbaDeprecationWarning:
# Fall-back from the nopython compilation path to the object mode compilation path has been detected, this is deprecated behaviour.
#
# For more information visit http://numba.pydata.org/numba-doc/latest/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit
#
# File "<ipython-input-2-8292d78451f9>", line 2:
# @jit
# def qwk(a1, a2):
# ^
#
#   warnings.warn(errors.NumbaDeprecationWarning(msg, state.func_ir.loc))
# Training until validation scores don't improve for 400 rounds
# [100]	training's rmse: 1.0608	training's cappa: 0.49734	valid_1's rmse: 1.07554	valid_1's cappa: 0.457939
# [200]	training's rmse: 0.98402	training's cappa: 0.630443	valid_1's rmse: 1.01335	valid_1's cappa: 0.587912
# [300]	training's rmse: 0.948048	training's cappa: 0.653073	valid_1's rmse: 0.991045	valid_1's cappa: 0.60336
# [400]	training's rmse: 0.925435	training's cappa: 0.663295	valid_1's rmse: 0.98164	valid_1's cappa: 0.606216
# [500]	training's rmse: 0.908679	training's cappa: 0.675403	valid_1's rmse: 0.977534	valid_1's cappa: 0.608347
# [600]	training's rmse: 0.894682	training's cappa: 0.685188	valid_1's rmse: 0.97531	valid_1's cappa: 0.60836
# [700]	training's rmse: 0.882178	training's cappa: 0.696636	valid_1's rmse: 0.974243	valid_1's cappa: 0.609029
# [800]	training's rmse: 0.87085	training's cappa: 0.70642	valid_1's rmse: 0.973839	valid_1's cappa: 0.608283
# [900]	training's rmse: 0.860395	training's cappa: 0.714186	valid_1's rmse: 0.973525	valid_1's cappa: 0.60816
# [1000]	training's rmse: 0.850622	training's cappa: 0.721863	valid_1's rmse: 0.973734	valid_1's cappa: 0.609577
# Early stopping, best iteration is:
# [651]	training's rmse: 0.888186	training's cappa: 0.691899	valid_1's rmse: 0.974637	valid_1's cappa: 0.611225
# parameter 9 48 0.3831152522726172 0.935490684648645 1 25.432614863571903 19.228797682674152
# score 0.9746367065703306
# |  1        | -0.9746   |  0.3831   |  25.43    |  19.23    |  9.897    |  48.25    |  0.9355   |  1.79     |
# /home/jupyter-shliu/.local/lib/python3.6/site-packages/lightgbm/engine.py:153: UserWarning: Found `early_stopping_rounds` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# /home/jupyter-shliu/.local/lib/python3.6/site-packages/lightgbm/basic.py:1236: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if self.categorical_feature == categorical_feature:
# /home/jupyter-shliu/.local/lib/python3.6/site-packages/lightgbm/basic.py:1242: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   elif categorical_feature == 'auto':
# /home/jupyter-shliu/.local/lib/python3.6/site-packages/lightgbm/basic.py:1247: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is []
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# Training until validation scores don't improve for 400 rounds
# [100]	training's rmse: 1.07077	training's cappa: 0.473561	valid_1's rmse: 1.07137	valid_1's cappa: 0.469593
# [200]	training's rmse: 1.01108	training's cappa: 0.595916	valid_1's rmse: 1.01626	valid_1's cappa: 0.588814
# [300]	training's rmse: 0.98598	training's cappa: 0.612682	valid_1's rmse: 0.996006	valid_1's cappa: 0.597713
# [400]	training's rmse: 0.971835	training's cappa: 0.620152	valid_1's rmse: 0.987378	valid_1's cappa: 0.598408
# [500]	training's rmse: 0.962033	training's cappa: 0.627046	valid_1's rmse: 0.983347	valid_1's cappa: 0.5991
# [600]	training's rmse: 0.954034	training's cappa: 0.632271	valid_1's rmse: 0.980161	valid_1's cappa: 0.603207
# [700]	training's rmse: 0.947511	training's cappa: 0.637398	valid_1's rmse: 0.979043	valid_1's cappa: 0.601843
# [800]	training's rmse: 0.941569	training's cappa: 0.64381	valid_1's rmse: 0.978069	valid_1's cappa: 0.60535
# [900]	training's rmse: 0.936225	training's cappa: 0.647265	valid_1's rmse: 0.977252	valid_1's cappa: 0.605221
# [1000]	training's rmse: 0.931194	training's cappa: 0.651451	valid_1's rmse: 0.976506	valid_1's cappa: 0.60691
# [1100]	training's rmse: 0.926486	training's cappa: 0.655101	valid_1's rmse: 0.976332	valid_1's cappa: 0.608338
# [1200]	training's rmse: 0.922318	training's cappa: 0.657719	valid_1's rmse: 0.97624	valid_1's cappa: 0.609169
# [1300]	training's rmse: 0.918195	training's cappa: 0.662185	valid_1's rmse: 0.975932	valid_1's cappa: 0.607859
# [1400]	training's rmse: 0.914249	training's cappa: 0.664689	valid_1's rmse: 0.975753	valid_1's cappa: 0.606817
# [1500]	training's rmse: 0.910524	training's cappa: 0.670101	valid_1's rmse: 0.975324	valid_1's cappa: 0.607523
# [1600]	training's rmse: 0.90686	training's cappa: 0.674634	valid_1's rmse: 0.975388	valid_1's cappa: 0.607657
# Early stopping, best iteration is:
# [1203]	training's rmse: 0.922186	training's cappa: 0.658176	valid_1's rmse: 0.976237	valid_1's cappa: 0.609842
# parameter 14 18 0.574762706437232 0.270286198776849 2 26.7619512637075 6.403437485546098
# score 0.9762368042860478
# |  2        | -0.9762   |  0.5748   |  26.76    |  6.403    |  14.43    |  18.79    |  0.2703   |  2.026    |
# Training until validation scores don't improve for 400 rounds
# [100]	training's rmse: 1.08449	training's cappa: 0.439396	valid_1's rmse: 1.09052	valid_1's cappa: 0.425357
# [200]	training's rmse: 1.01543	training's cappa: 0.597835	valid_1's rmse: 1.02804	valid_1's cappa: 0.576953
# [300]	training's rmse: 0.983689	training's cappa: 0.619553	valid_1's rmse: 1.00268	valid_1's cappa: 0.593339
# [400]	training's rmse: 0.965965	training's cappa: 0.627354	valid_1's rmse: 0.990561	valid_1's cappa: 0.599627
# [500]	training's rmse: 0.954304	training's cappa: 0.633154	valid_1's rmse: 0.984769	valid_1's cappa: 0.601927
# [600]	training's rmse: 0.945503	training's cappa: 0.639823	valid_1's rmse: 0.981441	valid_1's cappa: 0.603843
# [700]	training's rmse: 0.938236	training's cappa: 0.644904	valid_1's rmse: 0.979324	valid_1's cappa: 0.604921
# [800]	training's rmse: 0.931878	training's cappa: 0.650649	valid_1's rmse: 0.978193	valid_1's cappa: 0.606867
# [900]	training's rmse: 0.926192	training's cappa: 0.655398	valid_1's rmse: 0.977196	valid_1's cappa: 0.606667
# [1000]	training's rmse: 0.920937	training's cappa: 0.66083	valid_1's rmse: 0.976612	valid_1's cappa: 0.607844
# [1100]	training's rmse: 0.916191	training's cappa: 0.66461	valid_1's rmse: 0.976203	valid_1's cappa: 0.608385
# [1200]	training's rmse: 0.911844	training's cappa: 0.668731	valid_1's rmse: 0.975611	valid_1's cappa: 0.610372
# [1300]	training's rmse: 0.907778	training's cappa: 0.672109	valid_1's rmse: 0.975484	valid_1's cappa: 0.609108
# [1400]	training's rmse: 0.903988	training's cappa: 0.674758	valid_1's rmse: 0.975349	valid_1's cappa: 0.60928
# [1500]	training's rmse: 0.900476	training's cappa: 0.677854	valid_1's rmse: 0.975179	valid_1's cappa: 0.609792
# [1600]	training's rmse: 0.89722	training's cappa: 0.681888	valid_1's rmse: 0.975131	valid_1's cappa: 0.609824
# Early stopping, best iteration is:
# [1213]	training's rmse: 0.911273	training's cappa: 0.669082	valid_1's rmse: 0.975585	valid_1's cappa: 0.610918
# parameter 7 27 0.3666336007557807 0.8397323485806811 2 49.53769759047491 49.58728539120657
# score 0.9755845352707906
# |  3        | -0.9756   |  0.3666   |  49.54    |  49.59    |  7.759    |  27.93    |  0.8397   |  2.644    |
# Training until validation scores don't improve for 400 rounds
# [100]	training's rmse: 1.04039	training's cappa: 0.5636	valid_1's rmse: 1.05497	valid_1's cappa: 0.530793
# [200]	training's rmse: 0.966682	training's cappa: 0.644332	valid_1's rmse: 1.0008	valid_1's cappa: 0.597188
# [300]	training's rmse: 0.929466	training's cappa: 0.665425	valid_1's rmse: 0.983671	valid_1's cappa: 0.601804
# [400]	training's rmse: 0.904838	training's cappa: 0.681579	valid_1's rmse: 0.977437	valid_1's cappa: 0.604964
# [500]	training's rmse: 0.885091	training's cappa: 0.696711	valid_1's rmse: 0.975083	valid_1's cappa: 0.605638
# [600]	training's rmse: 0.867715	training's cappa: 0.710743	valid_1's rmse: 0.974286	valid_1's cappa: 0.60464
# [700]	training's rmse: 0.852272	training's cappa: 0.723052	valid_1's rmse: 0.973918	valid_1's cappa: 0.606511
# [800]	training's rmse: 0.838174	training's cappa: 0.734586	valid_1's rmse: 0.974002	valid_1's cappa: 0.60844
# [900]	training's rmse: 0.825064	training's cappa: 0.744095	valid_1's rmse: 0.974266	valid_1's cappa: 0.606565
# [1000]	training's rmse: 0.813198	training's cappa: 0.753706	valid_1's rmse: 0.974624	valid_1's cappa: 0.60793
# [1100]	training's rmse: 0.802214	training's cappa: 0.762878	valid_1's rmse: 0.974882	valid_1's cappa: 0.608253
# Early stopping, best iteration is:
# [716]	training's rmse: 0.849933	training's cappa: 0.725167	valid_1's rmse: 0.973784	valid_1's cappa: 0.606156
# parameter 9 81 0.6384414905296298 0.93535256387003 1 23.427150739090653 41.34249471876731
# score 0.9737837973510798
# |  4        | -0.9738   |  0.6384   |  23.43    |  41.34    |  9.998    |  81.32    |  0.9354   |  1.663    |
# Training until validation scores don't improve for 400 rounds
# [100]	training's rmse: 1.07602	training's cappa: 0.470119	valid_1's rmse: 1.08568	valid_1's cappa: 0.440137
# [200]	training's rmse: 0.999507	training's cappa: 0.614733	valid_1's rmse: 1.0208	valid_1's cappa: 0.585095
# [300]	training's rmse: 0.962345	training's cappa: 0.638879	valid_1's rmse: 0.995756	valid_1's cappa: 0.601346
# [400]	training's rmse: 0.939467	training's cappa: 0.653476	valid_1's rmse: 0.984933	valid_1's cappa: 0.603192
# [500]	training's rmse: 0.923109	training's cappa: 0.663816	valid_1's rmse: 0.9803	valid_1's cappa: 0.607744
# [600]	training's rmse: 0.909669	training's cappa: 0.673201	valid_1's rmse: 0.977915	valid_1's cappa: 0.605334
# [700]	training's rmse: 0.897563	training's cappa: 0.684457	valid_1's rmse: 0.976721	valid_1's cappa: 0.606084
# [800]	training's rmse: 0.887023	training's cappa: 0.692784	valid_1's rmse: 0.975971	valid_1's cappa: 0.604741
# [900]	training's rmse: 0.877103	training's cappa: 0.700752	valid_1's rmse: 0.975463	valid_1's cappa: 0.605741
# Early stopping, best iteration is:
# [529]	training's rmse: 0.919077	training's cappa: 0.667793	valid_1's rmse: 0.979663	valid_1's cappa: 0.608583
# parameter 13 45 0.3795169416975741 0.373635147680456 2 11.435178482643675 44.980334957224386
# score 0.9796632836602225
# |  5        | -0.9797   |  0.3795   |  11.44    |  44.98    |  13.77    |  45.21    |  0.3736   |  2.859    |
# Training until validation scores don't improve for 400 rounds
# [100]	training's rmse: 1.05985	training's cappa: 0.532704	valid_1's rmse: 1.06209	valid_1's cappa: 0.521198
# [200]	training's rmse: 1.00156	training's cappa: 0.604432	valid_1's rmse: 1.01181	valid_1's cappa: 0.588373
# [300]	training's rmse: 0.976275	training's cappa: 0.619988	valid_1's rmse: 0.995108	valid_1's cappa: 0.593732
# [400]	training's rmse: 0.960528	training's cappa: 0.628434	valid_1's rmse: 0.988201	valid_1's cappa: 0.596414
# [500]	training's rmse: 0.94934	training's cappa: 0.636507	valid_1's rmse: 0.984618	valid_1's cappa: 0.599064
# [600]	training's rmse: 0.940296	training's cappa: 0.644699	valid_1's rmse: 0.982531	valid_1's cappa: 0.602443
# [700]	training's rmse: 0.932736	training's cappa: 0.650874	valid_1's rmse: 0.98136	valid_1's cappa: 0.602917
# [800]	training's rmse: 0.926123	training's cappa: 0.656597	valid_1's rmse: 0.980447	valid_1's cappa: 0.604726
# [900]	training's rmse: 0.920069	training's cappa: 0.661655	valid_1's rmse: 0.979994	valid_1's cappa: 0.603888
# [1000]	training's rmse: 0.914446	training's cappa: 0.667228	valid_1's rmse: 0.979563	valid_1's cappa: 0.602929
# [1100]	training's rmse: 0.909293	training's cappa: 0.671801	valid_1's rmse: 0.979231	valid_1's cappa: 0.602551
# [1200]	training's rmse: 0.904401	training's cappa: 0.675323	valid_1's rmse: 0.979037	valid_1's cappa: 0.603986
# Early stopping, best iteration is:
# [802]	training's rmse: 0.926003	training's cappa: 0.65658	valid_1's rmse: 0.980402	valid_1's cappa: 0.604818
# parameter 8 57 0.9199653303822335 0.3752905791098924 1 38.32085949219965 12.157242676197122
# score 0.98040172020588
# |  6        | -0.9804   |  0.92     |  38.32    |  12.16    |  8.396    |  57.41    |  0.3753   |  1.706    |
# Training until validation scores don't improve for 400 rounds
# [100]	training's rmse: 1.05607	training's cappa: 0.536958	valid_1's rmse: 1.05844	valid_1's cappa: 0.526306
# [200]	training's rmse: 0.996249	training's cappa: 0.608163	valid_1's rmse: 1.00797	valid_1's cappa: 0.592175
# [300]	training's rmse: 0.970067	training's cappa: 0.622435	valid_1's rmse: 0.991547	valid_1's cappa: 0.598277
# [400]	training's rmse: 0.953552	training's cappa: 0.63326	valid_1's rmse: 0.984926	valid_1's cappa: 0.600576
# [500]	training's rmse: 0.94091	training's cappa: 0.643597	valid_1's rmse: 0.981739	valid_1's cappa: 0.600723
# [600]	training's rmse: 0.930659	training's cappa: 0.654176	valid_1's rmse: 0.980127	valid_1's cappa: 0.603202
# [700]	training's rmse: 0.921488	training's cappa: 0.659948	valid_1's rmse: 0.97903	valid_1's cappa: 0.602017
# [800]	training's rmse: 0.913353	training's cappa: 0.668287	valid_1's rmse: 0.978702	valid_1's cappa: 0.602017
# [900]	training's rmse: 0.905934	training's cappa: 0.674346	valid_1's rmse: 0.978316	valid_1's cappa: 0.603727
# [1000]	training's rmse: 0.899268	training's cappa: 0.67941	valid_1's rmse: 0.978394	valid_1's cappa: 0.605681
# [1100]	training's rmse: 0.89259	training's cappa: 0.685197	valid_1's rmse: 0.978568	valid_1's cappa: 0.604617
# [1200]	training's rmse: 0.886737	training's cappa: 0.689988	valid_1's rmse: 0.978253	valid_1's cappa: 0.6053
# [1300]	training's rmse: 0.880943	training's cappa: 0.695107	valid_1's rmse: 0.978314	valid_1's cappa: 0.605356
# [1400]	training's rmse: 0.875356	training's cappa: 0.701168	valid_1's rmse: 0.978972	valid_1's cappa: 0.605271
# Early stopping, best iteration is:
# [1042]	training's rmse: 0.896458	training's cappa: 0.682254	valid_1's rmse: 0.978303	valid_1's cappa: 0.607815
# parameter 8 95 0.9630761330781983 0.300085996254285 2 26.84391207024281 7.12005620323029
# score 0.9783026242505062
# |  7        | -0.9783   |  0.9631   |  26.84    |  7.12     |  8.416    |  95.84    |  0.3001   |  2.136    |
# Training until validation scores don't improve for 400 rounds
# [100]	training's rmse: 1.04069	training's cappa: 0.56476	valid_1's rmse: 1.05288	valid_1's cappa: 0.533606
# [200]	training's rmse: 0.973296	training's cappa: 0.631906	valid_1's rmse: 1.00228	valid_1's cappa: 0.598792
# [300]	training's rmse: 0.94063	training's cappa: 0.651507	valid_1's rmse: 0.986326	valid_1's cappa: 0.599509
# [400]	training's rmse: 0.918737	training's cappa: 0.669461	valid_1's rmse: 0.98086	valid_1's cappa: 0.603389
# [500]	training's rmse: 0.901578	training's cappa: 0.681762	valid_1's rmse: 0.978894	valid_1's cappa: 0.601313
# [600]	training's rmse: 0.886689	training's cappa: 0.692585	valid_1's rmse: 0.977697	valid_1's cappa: 0.602838
# [700]	training's rmse: 0.873679	training's cappa: 0.703491	valid_1's rmse: 0.976759	valid_1's cappa: 0.606275
# [800]	training's rmse: 0.861867	training's cappa: 0.712183	valid_1's rmse: 0.97687	valid_1's cappa: 0.608068
# [900]	training's rmse: 0.850793	training's cappa: 0.722928	valid_1's rmse: 0.976809	valid_1's cappa: 0.608484
# [1000]	training's rmse: 0.840708	training's cappa: 0.732109	valid_1's rmse: 0.977269	valid_1's cappa: 0.606072
# [1100]	training's rmse: 0.831231	training's cappa: 0.740892	valid_1's rmse: 0.977359	valid_1's cappa: 0.607821
# Early stopping, best iteration is:
# [744]	training's rmse: 0.868613	training's cappa: 0.707172	valid_1's rmse: 0.976499	valid_1's cappa: 0.606846
# parameter 13 62 0.7161623541782525 0.563611060922063 2 26.951506153237958 1.0210194628016123
# score 0.9764987790630754
# |  8        | -0.9765   |  0.7162   |  26.95    |  1.021    |  13.58    |  62.1     |  0.5636   |  2.171    |
# Training until validation scores don't improve for 400 rounds
# [100]	training's rmse: 1.07466	training's cappa: 0.472653	valid_1's rmse: 1.08658	valid_1's cappa: 0.441329
# [200]	training's rmse: 1.00129	training's cappa: 0.613386	valid_1's rmse: 1.02458	valid_1's cappa: 0.581243
# [300]	training's rmse: 0.966586	training's cappa: 0.635501	valid_1's rmse: 0.99994	valid_1's cappa: 0.597275
# [400]	training's rmse: 0.946272	training's cappa: 0.648416	valid_1's rmse: 0.988671	valid_1's cappa: 0.603331
# [500]	training's rmse: 0.931885	training's cappa: 0.65697	valid_1's rmse: 0.983648	valid_1's cappa: 0.604306
# [600]	training's rmse: 0.920447	training's cappa: 0.664836	valid_1's rmse: 0.980565	valid_1's cappa: 0.60495
# [700]	training's rmse: 0.910433	training's cappa: 0.672414	valid_1's rmse: 0.978882	valid_1's cappa: 0.605133
# [800]	training's rmse: 0.90169	training's cappa: 0.679143	valid_1's rmse: 0.977928	valid_1's cappa: 0.606865
# [900]	training's rmse: 0.893877	training's cappa: 0.686065	valid_1's rmse: 0.977255	valid_1's cappa: 0.608348
# [1000]	training's rmse: 0.88664	training's cappa: 0.692199	valid_1's rmse: 0.976896	valid_1's cappa: 0.607619
# [1100]	training's rmse: 0.879792	training's cappa: 0.698881	valid_1's rmse: 0.976457	valid_1's cappa: 0.60659
# [1200]	training's rmse: 0.873545	training's cappa: 0.703923	valid_1's rmse: 0.9764	valid_1's cappa: 0.607683
# [1300]	training's rmse: 0.867804	training's cappa: 0.707986	valid_1's rmse: 0.976339	valid_1's cappa: 0.607028
# Early stopping, best iteration is:
# [967]	training's rmse: 0.889071	training's cappa: 0.690184	valid_1's rmse: 0.976981	valid_1's cappa: 0.609021
# parameter 15 51 0.3648061263505626 0.7686102771342134 1 40.81963129762505 38.401219287875364
# score 0.9769810835439391
# |  9        | -0.977    |  0.3648   |  40.82    |  38.4     |  15.49    |  51.07    |  0.7686   |  1.583    |
# Training until validation scores don't improve for 400 rounds
# [100]	training's rmse: 1.06536	training's cappa: 0.487682	valid_1's rmse: 1.07222	valid_1's cappa: 0.463766
# [200]	training's rmse: 0.998723	training's cappa: 0.610864	valid_1's rmse: 1.01399	valid_1's cappa: 0.587975
# [300]	training's rmse: 0.969012	training's cappa: 0.62831	valid_1's rmse: 0.992479	valid_1's cappa: 0.599907
# [400]	training's rmse: 0.95072	training's cappa: 0.63813	valid_1's rmse: 0.983019	valid_1's cappa: 0.602069
# [500]	training's rmse: 0.937965	training's cappa: 0.647541	valid_1's rmse: 0.978875	valid_1's cappa: 0.603119
# [600]	training's rmse: 0.927909	training's cappa: 0.653983	valid_1's rmse: 0.976698	valid_1's cappa: 0.604327
# [700]	training's rmse: 0.919121	training's cappa: 0.662414	valid_1's rmse: 0.975618	valid_1's cappa: 0.605332
# [800]	training's rmse: 0.911031	training's cappa: 0.671044	valid_1's rmse: 0.975138	valid_1's cappa: 0.607934
# [900]	training's rmse: 0.903703	training's cappa: 0.677109	valid_1's rmse: 0.97476	valid_1's cappa: 0.608468
# [1000]	training's rmse: 0.896886	training's cappa: 0.682361	valid_1's rmse: 0.974478	valid_1's cappa: 0.607892
# [1100]	training's rmse: 0.890646	training's cappa: 0.687817	valid_1's rmse: 0.974288	valid_1's cappa: 0.606862
# [1200]	training's rmse: 0.884797	training's cappa: 0.692639	valid_1's rmse: 0.974312	valid_1's cappa: 0.606343
# [1300]	training's rmse: 0.879475	training's cappa: 0.697685	valid_1's rmse: 0.974426	valid_1's cappa: 0.606112
# Early stopping, best iteration is:
# [966]	training's rmse: 0.899095	training's cappa: 0.680695	valid_1's rmse: 0.974523	valid_1's cappa: 0.609567
# parameter 6 98 0.4824597171865502 0.9282635990090762 1 36.438679781746764 7.781564101687841
# score 0.9745232599562138
# |  10       | -0.9745   |  0.4825   |  36.44    |  7.782    |  6.104    |  98.67    |  0.9283   |  1.178    |
# Training until validation scores don't improve for 400 rounds
# [100]	training's rmse: 1.05132	training's cappa: 0.538534	valid_1's rmse: 1.06033	valid_1's cappa: 0.51488
# [200]	training's rmse: 0.981434	training's cappa: 0.627199	valid_1's rmse: 1.003	valid_1's cappa: 0.595867
# [300]	training's rmse: 0.948943	training's cappa: 0.645324	valid_1's rmse: 0.983751	valid_1's cappa: 0.602184
# [400]	training's rmse: 0.928804	training's cappa: 0.658135	valid_1's rmse: 0.976855	valid_1's cappa: 0.605382
# [500]	training's rmse: 0.913176	training's cappa: 0.670298	valid_1's rmse: 0.974305	valid_1's cappa: 0.607043
# [600]	training's rmse: 0.900015	training's cappa: 0.682167	valid_1's rmse: 0.97314	valid_1's cappa: 0.607144
# [700]	training's rmse: 0.888096	training's cappa: 0.692509	valid_1's rmse: 0.972663	valid_1's cappa: 0.608261
# [800]	training's rmse: 0.877251	training's cappa: 0.69997	valid_1's rmse: 0.97255	valid_1's cappa: 0.610336
# [900]	training's rmse: 0.866979	training's cappa: 0.708569	valid_1's rmse: 0.972704	valid_1's cappa: 0.613004
# [1000]	training's rmse: 0.857492	training's cappa: 0.717438	valid_1's rmse: 0.972696	valid_1's cappa: 0.611071
# [1100]	training's rmse: 0.848642	training's cappa: 0.725506	valid_1's rmse: 0.973002	valid_1's cappa: 0.613453
# Early stopping, best iteration is:
# [780]	training's rmse: 0.879304	training's cappa: 0.698516	valid_1's rmse: 0.972486	valid_1's cappa: 0.610782
# parameter 13 35 0.5896676319954925 0.6056047067107262 1 10.85971061904395 49.55314838154636
# score 0.9724862487508067
# |  11       | -0.9725   |  0.5897   |  10.86    |  49.55    |  13.44    |  35.97    |  0.6056   |  1.336    |
# Training until validation scores don't improve for 400 rounds
# [100]	training's rmse: 1.06761	training's cappa: 0.5078	valid_1's rmse: 1.06935	valid_1's cappa: 0.495937
# [200]	training's rmse: 1.0101	training's cappa: 0.596079	valid_1's rmse: 1.01921	valid_1's cappa: 0.582518
# [300]	training's rmse: 0.986107	training's cappa: 0.611838	valid_1's rmse: 1.00153	valid_1's cappa: 0.589291
# [400]	training's rmse: 0.971862	training's cappa: 0.619599	valid_1's rmse: 0.993786	valid_1's cappa: 0.595464
# [500]	training's rmse: 0.961567	training's cappa: 0.627308	valid_1's rmse: 0.989468	valid_1's cappa: 0.596823
# [600]	training's rmse: 0.953606	training's cappa: 0.632295	valid_1's rmse: 0.986923	valid_1's cappa: 0.599548
# [700]	training's rmse: 0.947192	training's cappa: 0.637127	valid_1's rmse: 0.985655	valid_1's cappa: 0.599722
# [800]	training's rmse: 0.941399	training's cappa: 0.643518	valid_1's rmse: 0.984518	valid_1's cappa: 0.599007
# [900]	training's rmse: 0.936425	training's cappa: 0.648021	valid_1's rmse: 0.983658	valid_1's cappa: 0.602624
# [1000]	training's rmse: 0.931816	training's cappa: 0.652003	valid_1's rmse: 0.983182	valid_1's cappa: 0.602402
# [1100]	training's rmse: 0.927503	training's cappa: 0.65551	valid_1's rmse: 0.982591	valid_1's cappa: 0.602899
# [1200]	training's rmse: 0.923408	training's cappa: 0.657759	valid_1's rmse: 0.981964	valid_1's cappa: 0.601713
# [1300]	training's rmse: 0.919634	training's cappa: 0.662043	valid_1's rmse: 0.981726	valid_1's cappa: 0.601218
# [1400]	training's rmse: 0.915849	training's cappa: 0.665581	valid_1's rmse: 0.981357	valid_1's cappa: 0.602103
# [1500]	training's rmse: 0.912499	training's cappa: 0.668308	valid_1's rmse: 0.980987	valid_1's cappa: 0.60293
# [1600]	training's rmse: 0.909065	training's cappa: 0.671321	valid_1's rmse: 0.980796	valid_1's cappa: 0.604914
# [1700]	training's rmse: 0.905881	training's cappa: 0.673555	valid_1's rmse: 0.980628	valid_1's cappa: 0.604132
# [1800]	training's rmse: 0.902552	training's cappa: 0.676241	valid_1's rmse: 0.98061	valid_1's cappa: 0.602081
# [1900]	training's rmse: 0.899597	training's cappa: 0.679053	valid_1's rmse: 0.980594	valid_1's cappa: 0.600299
# Early stopping, best iteration is:
# [1593]	training's rmse: 0.909301	training's cappa: 0.671544	valid_1's rmse: 0.980852	valid_1's cappa: 0.605657
# parameter 12 63 0.9800513662075327 0.35611484150714773 2 49.65064362660622 37.91072271154383
# score 0.9808521907004204
# |  12       | -0.9809   |  0.9801   |  49.65    |  37.91    |  12.49    |  63.04    |  0.3561   |  2.125    |
# Training until validation scores don't improve for 400 rounds
# [100]	training's rmse: 1.07366	training's cappa: 0.464441	valid_1's rmse: 1.07887	valid_1's cappa: 0.4468
# [200]	training's rmse: 1.00747	training's cappa: 0.601633	valid_1's rmse: 1.01924	valid_1's cappa: 0.58288
# [300]	training's rmse: 0.977789	training's cappa: 0.619482	valid_1's rmse: 0.996358	valid_1's cappa: 0.597639
# [400]	training's rmse: 0.96069	training's cappa: 0.629731	valid_1's rmse: 0.985958	valid_1's cappa: 0.603653
# [500]	training's rmse: 0.94867	training's cappa: 0.638511	valid_1's rmse: 0.980988	valid_1's cappa: 0.603011
# [600]	training's rmse: 0.939191	training's cappa: 0.645219	valid_1's rmse: 0.978139	valid_1's cappa: 0.60735
# [700]	training's rmse: 0.931039	training's cappa: 0.650206	valid_1's rmse: 0.976559	valid_1's cappa: 0.606825
# [800]	training's rmse: 0.923978	training's cappa: 0.657826	valid_1's rmse: 0.975893	valid_1's cappa: 0.60832
# [900]	training's rmse: 0.917625	training's cappa: 0.662504	valid_1's rmse: 0.975346	valid_1's cappa: 0.610214
# [1000]	training's rmse: 0.911738	training's cappa: 0.66908	valid_1's rmse: 0.975049	valid_1's cappa: 0.606979
# [1100]	training's rmse: 0.906306	training's cappa: 0.673631	valid_1's rmse: 0.974744	valid_1's cappa: 0.606907
# [1200]	training's rmse: 0.90132	training's cappa: 0.676908	valid_1's rmse: 0.974502	valid_1's cappa: 0.607777
# [1300]	training's rmse: 0.896508	training's cappa: 0.680684	valid_1's rmse: 0.974323	valid_1's cappa: 0.608491
# Early stopping, best iteration is:
# [900]	training's rmse: 0.917625	training's cappa: 0.662504	valid_1's rmse: 0.975346	valid_1's cappa: 0.610214
# parameter 6 29 0.4726932193173401 0.8250206550811683 1 39.380951386196784 38.67148878889893
# score 0.9753459690606122
# |  13       | -0.9753   |  0.4727   |  39.38    |  38.67    |  6.041    |  29.24    |  0.825    |  1.074    |
# Training until validation scores don't improve for 400 rounds
# [100]	training's rmse: 1.05694	training's cappa: 0.539368	valid_1's rmse: 1.06159	valid_1's cappa: 0.527957
# [200]	training's rmse: 0.997199	training's cappa: 0.610503	valid_1's rmse: 1.01162	valid_1's cappa: 0.591337
# [300]	training's rmse: 0.970666	training's cappa: 0.62508	valid_1's rmse: 0.994727	valid_1's cappa: 0.598032
# [400]	training's rmse: 0.953919	training's cappa: 0.63403	valid_1's rmse: 0.98767	valid_1's cappa: 0.59808
# [500]	training's rmse: 0.942045	training's cappa: 0.642267	valid_1's rmse: 0.984431	valid_1's cappa: 0.599783
# [600]	training's rmse: 0.932651	training's cappa: 0.649554	valid_1's rmse: 0.982243	valid_1's cappa: 0.601071
# [700]	training's rmse: 0.924343	training's cappa: 0.65706	valid_1's rmse: 0.98101	valid_1's cappa: 0.600738
# [800]	training's rmse: 0.917196	training's cappa: 0.66275	valid_1's rmse: 0.980075	valid_1's cappa: 0.602657
# [900]	training's rmse: 0.910863	training's cappa: 0.669872	valid_1's rmse: 0.979596	valid_1's cappa: 0.603107
# [1000]	training's rmse: 0.905273	training's cappa: 0.674354	valid_1's rmse: 0.979268	valid_1's cappa: 0.603602
# [1100]	training's rmse: 0.900045	training's cappa: 0.678949	valid_1's rmse: 0.978921	valid_1's cappa: 0.601905
# [1200]	training's rmse: 0.89539	training's cappa: 0.683401	valid_1's rmse: 0.978644	valid_1's cappa: 0.60346
# [1300]	training's rmse: 0.89067	training's cappa: 0.68743	valid_1's rmse: 0.978744	valid_1's cappa: 0.604445
# [1400]	training's rmse: 0.886116	training's cappa: 0.691143	valid_1's rmse: 0.978479	valid_1's cappa: 0.605252
# [1500]	training's rmse: 0.881986	training's cappa: 0.694766	valid_1's rmse: 0.978264	valid_1's cappa: 0.604709
# [1600]	training's rmse: 0.8779	training's cappa: 0.698587	valid_1's rmse: 0.978214	valid_1's cappa: 0.604513
# [1700]	training's rmse: 0.874313	training's cappa: 0.702016	valid_1's rmse: 0.978408	valid_1's cappa: 0.604668
# [1800]	training's rmse: 0.870792	training's cappa: 0.704327	valid_1's rmse: 0.97838	valid_1's cappa: 0.602967
# [1900]	training's rmse: 0.867426	training's cappa: 0.707438	valid_1's rmse: 0.978384	valid_1's cappa: 0.603408
# [2000]	training's rmse: 0.864255	training's cappa: 0.710373	valid_1's rmse: 0.97843	valid_1's cappa: 0.604631
# Early stopping, best iteration is:
# [1627]	training's rmse: 0.877024	training's cappa: 0.699157	valid_1's rmse: 0.978113	valid_1's cappa: 0.606051
# parameter 9 65 0.893428609439153 0.5825564607322569 2 47.42817839307865 27.00384959958749
# score 0.9781128146789201
# |  14       | -0.9781   |  0.8934   |  47.43    |  27.0     |  9.105    |  65.6     |  0.5826   |  2.719    |
# Training until validation scores don't improve for 400 rounds
# [100]	training's rmse: 1.05726	training's cappa: 0.527765	valid_1's rmse: 1.06119	valid_1's cappa: 0.510576
# [200]	training's rmse: 0.996626	training's cappa: 0.608448	valid_1's rmse: 1.00858	valid_1's cappa: 0.591844
# [300]	training's rmse: 0.969844	training's cappa: 0.622104	valid_1's rmse: 0.990092	valid_1's cappa: 0.598948
# [400]	training's rmse: 0.953277	training's cappa: 0.633446	valid_1's rmse: 0.98206	valid_1's cappa: 0.604405
# [500]	training's rmse: 0.940836	training's cappa: 0.643517	valid_1's rmse: 0.978545	valid_1's cappa: 0.603479
# [600]	training's rmse: 0.931009	training's cappa: 0.651032	valid_1's rmse: 0.976681	valid_1's cappa: 0.605479
# [700]	training's rmse: 0.922429	training's cappa: 0.659522	valid_1's rmse: 0.975685	valid_1's cappa: 0.606336
# [800]	training's rmse: 0.915009	training's cappa: 0.666316	valid_1's rmse: 0.97513	valid_1's cappa: 0.607927
# [900]	training's rmse: 0.908219	training's cappa: 0.672874	valid_1's rmse: 0.97464	valid_1's cappa: 0.607473
# [1000]	training's rmse: 0.902001	training's cappa: 0.677416	valid_1's rmse: 0.974443	valid_1's cappa: 0.606847
# [1100]	training's rmse: 0.896307	training's cappa: 0.682295	valid_1's rmse: 0.974162	valid_1's cappa: 0.607779
# [1200]	training's rmse: 0.891064	training's cappa: 0.687886	valid_1's rmse: 0.974065	valid_1's cappa: 0.607627
# Early stopping, best iteration is:
# [828]	training's rmse: 0.91309	training's cappa: 0.66846	valid_1's rmse: 0.974996	valid_1's cappa: 0.609457
# parameter 6 79 0.6461458178057019 0.8067966614034865 1 39.19690327182777 2.8211532264368513
# score 0.9749957871622121
# |  15       | -0.975    |  0.6461   |  39.2     |  2.821    |  6.807    |  79.21    |  0.8068   |  1.183    |
# Training until validation scores don't improve for 400 rounds
# [100]	training's rmse: 1.07642	training's cappa: 0.455811	valid_1's rmse: 1.0833	valid_1's cappa: 0.431767
# [200]	training's rmse: 1.00426	training's cappa: 0.608721	valid_1's rmse: 1.01901	valid_1's cappa: 0.581756
# [300]	training's rmse: 0.969683	training's cappa: 0.629972	valid_1's rmse: 0.992785	valid_1's cappa: 0.604527
# [400]	training's rmse: 0.949699	training's cappa: 0.642607	valid_1's rmse: 0.981659	valid_1's cappa: 0.608509
# [500]	training's rmse: 0.935727	training's cappa: 0.651423	valid_1's rmse: 0.976882	valid_1's cappa: 0.607913
# [600]	training's rmse: 0.924485	training's cappa: 0.65922	valid_1's rmse: 0.974423	valid_1's cappa: 0.609088
# [700]	training's rmse: 0.914658	training's cappa: 0.66728	valid_1's rmse: 0.972984	valid_1's cappa: 0.612765
# [800]	training's rmse: 0.905927	training's cappa: 0.674414	valid_1's rmse: 0.972149	valid_1's cappa: 0.613727
# [900]	training's rmse: 0.89762	training's cappa: 0.682981	valid_1's rmse: 0.971527	valid_1's cappa: 0.61591
# [1000]	training's rmse: 0.889898	training's cappa: 0.689504	valid_1's rmse: 0.971323	valid_1's cappa: 0.614851
# [1100]	training's rmse: 0.882571	training's cappa: 0.695303	valid_1's rmse: 0.971385	valid_1's cappa: 0.614833
# [1200]	training's rmse: 0.875808	training's cappa: 0.701009	valid_1's rmse: 0.971344	valid_1's cappa: 0.612126
# [1300]	training's rmse: 0.869237	training's cappa: 0.70576	valid_1's rmse: 0.971428	valid_1's cappa: 0.611648
# Early stopping, best iteration is:
# [914]	training's rmse: 0.896504	training's cappa: 0.683367	valid_1's rmse: 0.97141	valid_1's cappa: 0.616459
# parameter 11 20 0.31063250675672993 0.8817020786968552 1 7.1224957886334295 27.312172140570397
# score 0.9714104539564845
# |  16       | -0.9714   |  0.3106   |  7.122    |  27.31    |  11.12    |  20.47    |  0.8817   |  1.989    |
# Training until validation scores don't improve for 400 rounds
# [100]	training's rmse: 1.09082	training's cappa: 0.423818	valid_1's rmse: 1.09391	valid_1's cappa: 0.410416
# [200]	training's rmse: 1.02389	training's cappa: 0.583972	valid_1's rmse: 1.03113	valid_1's cappa: 0.571248
# [300]	training's rmse: 0.993389	training's cappa: 0.608301	valid_1's rmse: 1.00461	valid_1's cappa: 0.592914
# [400]	training's rmse: 0.976635	training's cappa: 0.617993	valid_1's rmse: 0.992239	valid_1's cappa: 0.596565
# [500]	training's rmse: 0.965581	training's cappa: 0.625652	valid_1's rmse: 0.985963	valid_1's cappa: 0.600429
# [600]	training's rmse: 0.957239	training's cappa: 0.629638	valid_1's rmse: 0.982315	valid_1's cappa: 0.601352
# [700]	training's rmse: 0.950387	training's cappa: 0.634169	valid_1's rmse: 0.980224	valid_1's cappa: 0.602377
# [800]	training's rmse: 0.944636	training's cappa: 0.639113	valid_1's rmse: 0.978746	valid_1's cappa: 0.603698
# [900]	training's rmse: 0.939508	training's cappa: 0.644403	valid_1's rmse: 0.977675	valid_1's cappa: 0.605609
# [1000]	training's rmse: 0.934774	training's cappa: 0.646397	valid_1's rmse: 0.976722	valid_1's cappa: 0.604997
# [1100]	training's rmse: 0.930499	training's cappa: 0.650894	valid_1's rmse: 0.976201	valid_1's cappa: 0.606088
# [1200]	training's rmse: 0.926372	training's cappa: 0.656507	valid_1's rmse: 0.975893	valid_1's cappa: 0.608396
# [1300]	training's rmse: 0.922494	training's cappa: 0.660963	valid_1's rmse: 0.975626	valid_1's cappa: 0.608577
# [1400]	training's rmse: 0.918824	training's cappa: 0.663624	valid_1's rmse: 0.975317	valid_1's cappa: 0.608921
# [1500]	training's rmse: 0.915228	training's cappa: 0.66632	valid_1's rmse: 0.974904	valid_1's cappa: 0.609401
# [1600]	training's rmse: 0.911945	training's cappa: 0.668832	valid_1's rmse: 0.974785	valid_1's cappa: 0.61015
# [1700]	training's rmse: 0.908734	training's cappa: 0.671635	valid_1's rmse: 0.974747	valid_1's cappa: 0.609805
# Early stopping, best iteration is:
# [1383]	training's rmse: 0.919467	training's cappa: 0.663227	valid_1's rmse: 0.975387	valid_1's cappa: 0.61047
# parameter 5 18 0.3590036908802307 0.6707109519083818 1 36.26200800449452 34.56752261776136
# score 0.9753871957848514
# |  17       | -0.9754   |  0.359    |  36.26    |  34.57    |  5.549    |  18.48    |  0.6707   |  1.24     |
# Training until validation scores don't improve for 400 rounds
# [100]	training's rmse: 1.0456	training's cappa: 0.560857	valid_1's rmse: 1.05648	valid_1's cappa: 0.535053
# [200]	training's rmse: 0.978636	training's cappa: 0.630321	valid_1's rmse: 1.00458	valid_1's cappa: 0.592878
# [300]	training's rmse: 0.946977	training's cappa: 0.646638	valid_1's rmse: 0.987537	valid_1's cappa: 0.599214
# [400]	training's rmse: 0.926342	training's cappa: 0.660122	valid_1's rmse: 0.98098	valid_1's cappa: 0.601262
# [500]	training's rmse: 0.910322	training's cappa: 0.674565	valid_1's rmse: 0.978242	valid_1's cappa: 0.601957
# [600]	training's rmse: 0.89676	training's cappa: 0.684067	valid_1's rmse: 0.977044	valid_1's cappa: 0.60215
# [700]	training's rmse: 0.884896	training's cappa: 0.694616	valid_1's rmse: 0.976314	valid_1's cappa: 0.602186
# [800]	training's rmse: 0.874213	training's cappa: 0.70348	valid_1's rmse: 0.975918	valid_1's cappa: 0.6053
# [900]	training's rmse: 0.86431	training's cappa: 0.711221	valid_1's rmse: 0.975692	valid_1's cappa: 0.607269
# [1000]	training's rmse: 0.855287	training's cappa: 0.719226	valid_1's rmse: 0.975596	valid_1's cappa: 0.607154
# [1100]	training's rmse: 0.846851	training's cappa: 0.726518	valid_1's rmse: 0.975652	valid_1's cappa: 0.606726
# [1200]	training's rmse: 0.83876	training's cappa: 0.733115	valid_1's rmse: 0.975608	valid_1's cappa: 0.608163
# [1300]	training's rmse: 0.831501	training's cappa: 0.740408	valid_1's rmse: 0.975744	valid_1's cappa: 0.607919
# Early stopping, best iteration is:
# [983]	training's rmse: 0.856768	training's cappa: 0.717684	valid_1's rmse: 0.97555	valid_1's cappa: 0.607907
# parameter 11 52 0.7506112752856493 0.9616714914399644 1 35.28394279333552 47.20058704849561
# score 0.9755495415579283
# |  18       | -0.9755   |  0.7506   |  35.28    |  47.2     |  11.91    |  52.1     |  0.9617   |  1.285    |
# Training until validation scores don't improve for 400 rounds
# [100]	training's rmse: 1.04824	training's cappa: 0.556159	valid_1's rmse: 1.05877	valid_1's cappa: 0.533201
# [200]	training's rmse: 0.982045	training's cappa: 0.627692	valid_1's rmse: 1.00688	valid_1's cappa: 0.595402
# [300]	training's rmse: 0.950637	training's cappa: 0.642819	valid_1's rmse: 0.989775	valid_1's cappa: 0.59835
# [400]	training's rmse: 0.930443	training's cappa: 0.656827	valid_1's rmse: 0.983033	valid_1's cappa: 0.601706
# [500]	training's rmse: 0.915114	training's cappa: 0.668416	valid_1's rmse: 0.980194	valid_1's cappa: 0.601678
# [600]	training's rmse: 0.902339	training's cappa: 0.677545	valid_1's rmse: 0.979026	valid_1's cappa: 0.601524
# [700]	training's rmse: 0.891195	training's cappa: 0.688452	valid_1's rmse: 0.978088	valid_1's cappa: 0.599747
# [800]	training's rmse: 0.881719	training's cappa: 0.695621	valid_1's rmse: 0.977789	valid_1's cappa: 0.600616
# Early stopping, best iteration is:
# [426]	training's rmse: 0.926287	training's cappa: 0.660296	valid_1's rmse: 0.981988	valid_1's cappa: 0.602839
# parameter 12 62 0.7375459662973944 0.9461811652336578 1 45.42359526088987 40.19242313326685
# score 0.9819876804596989
# |  19       | -0.982    |  0.7375   |  45.42    |  40.19    |  12.41    |  62.87    |  0.9462   |  1.324    |
# Training until validation scores don't improve for 400 rounds
# [100]	training's rmse: 1.0154	training's cappa: 0.606984	valid_1's rmse: 1.04807	valid_1's cappa: 0.538694
# [200]	training's rmse: 0.924865	training's cappa: 0.690782	valid_1's rmse: 0.993549	valid_1's cappa: 0.601531
# [300]	training's rmse: 0.87563	training's cappa: 0.715746	valid_1's rmse: 0.978129	valid_1's cappa: 0.606073
# [400]	training's rmse: 0.840017	training's cappa: 0.738078	valid_1's rmse: 0.973868	valid_1's cappa: 0.608878
# [500]	training's rmse: 0.810941	training's cappa: 0.75826	valid_1's rmse: 0.972957	valid_1's cappa: 0.608946
# [600]	training's rmse: 0.784956	training's cappa: 0.776989	valid_1's rmse: 0.973536	valid_1's cappa: 0.609599
# [700]	training's rmse: 0.761805	training's cappa: 0.795085	valid_1's rmse: 0.974119	valid_1's cappa: 0.611183
# [800]	training's rmse: 0.740837	training's cappa: 0.80945	valid_1's rmse: 0.975233	valid_1's cappa: 0.610313
# [900]	training's rmse: 0.721394	training's cappa: 0.82251	valid_1's rmse: 0.976241	valid_1's cappa: 0.610846
# Early stopping, best iteration is:
# [511]	training's rmse: 0.80793	training's cappa: 0.759801	valid_1's rmse: 0.972787	valid_1's cappa: 0.607759
# parameter 15 84 0.5443287672868025 0.8192414682085434 1 5.5668119340946856 19.804032597915366
# score 0.9727870298761639
# |  20       | -0.9728   |  0.5443   |  5.567    |  19.8     |  15.49    |  84.83    |  0.8192   |  1.74     |
# Training until validation scores don't improve for 400 rounds
# [100]	training's rmse: 1.04262	training's cappa: 0.543456	valid_1's rmse: 1.06812	valid_1's cappa: 0.4819
# [200]	training's rmse: 0.954867	training's cappa: 0.664209	valid_1's rmse: 1.00577	valid_1's cappa: 0.593367
# [300]	training's rmse: 0.909836	training's cappa: 0.689301	valid_1's rmse: 0.985493	valid_1's cappa: 0.606867
# [400]	training's rmse: 0.878732	training's cappa: 0.707366	valid_1's rmse: 0.97737	valid_1's cappa: 0.609434
# [500]	training's rmse: 0.853995	training's cappa: 0.722978	valid_1's rmse: 0.975297	valid_1's cappa: 0.608961
# [600]	training's rmse: 0.832473	training's cappa: 0.740087	valid_1's rmse: 0.974752	valid_1's cappa: 0.608071
# [700]	training's rmse: 0.813581	training's cappa: 0.755891	valid_1's rmse: 0.974601	valid_1's cappa: 0.608116
# [800]	training's rmse: 0.796515	training's cappa: 0.767716	valid_1's rmse: 0.974684	valid_1's cappa: 0.609438
# [900]	training's rmse: 0.780572	training's cappa: 0.781012	valid_1's rmse: 0.975209	valid_1's cappa: 0.60801
# Early stopping, best iteration is:
# [555]	training's rmse: 0.841772	training's cappa: 0.73265	valid_1's rmse: 0.975023	valid_1's cappa: 0.610413
# parameter 12 83 0.4079083430486944 0.6779306179193103 1 11.815451100017292 14.156802092690336
# score 0.9750233112540182
# |  21       | -0.975    |  0.4079   |  11.82    |  14.16    |  12.39    |  83.5     |  0.6779   |  1.542    |
# Training until validation scores don't improve for 400 rounds
# [100]	training's rmse: 1.05593	training's cappa: 0.544258	valid_1's rmse: 1.05993	valid_1's cappa: 0.527782
# [200]	training's rmse: 0.997884	training's cappa: 0.610641	valid_1's rmse: 1.01088	valid_1's cappa: 0.593238
# [300]	training's rmse: 0.973016	training's cappa: 0.62333	valid_1's rmse: 0.994699	valid_1's cappa: 0.597892
# [400]	training's rmse: 0.95757	training's cappa: 0.632649	valid_1's rmse: 0.987886	valid_1's cappa: 0.598504
# [500]	training's rmse: 0.946425	training's cappa: 0.639465	valid_1's rmse: 0.984883	valid_1's cappa: 0.600088
# [600]	training's rmse: 0.937025	training's cappa: 0.647737	valid_1's rmse: 0.982903	valid_1's cappa: 0.599392
# [700]	training's rmse: 0.929033	training's cappa: 0.654364	valid_1's rmse: 0.981563	valid_1's cappa: 0.598682
# [800]	training's rmse: 0.921843	training's cappa: 0.660303	valid_1's rmse: 0.980715	valid_1's cappa: 0.600006
# Early stopping, best iteration is:
# [464]	training's rmse: 0.950192	training's cappa: 0.637026	valid_1's rmse: 0.98593	valid_1's cappa: 0.601887
# parameter 11 32 0.9866529343010353 0.49234871764273785 2 44.13097524104235 17.075827978000707
# score 0.985930203082093
# |  22       | -0.9859   |  0.9867   |  44.13    |  17.08    |  11.44    |  32.56    |  0.4923   |  2.76     |
# Training until validation scores don't improve for 400 rounds
# [100]	training's rmse: 1.07018	training's cappa: 0.472308	valid_1's rmse: 1.0742	valid_1's cappa: 0.461595
# [200]	training's rmse: 1.00574	training's cappa: 0.60301	valid_1's rmse: 1.01754	valid_1's cappa: 0.586774
# [300]	training's rmse: 0.977125	training's cappa: 0.620087	valid_1's rmse: 0.996393	valid_1's cappa: 0.595035
# [400]	training's rmse: 0.959642	training's cappa: 0.631624	valid_1's rmse: 0.987888	valid_1's cappa: 0.600545
# [500]	training's rmse: 0.947049	training's cappa: 0.640956	valid_1's rmse: 0.98417	valid_1's cappa: 0.602839
# [600]	training's rmse: 0.936557	training's cappa: 0.649263	valid_1's rmse: 0.981374	valid_1's cappa: 0.604101
# [700]	training's rmse: 0.927464	training's cappa: 0.655848	valid_1's rmse: 0.979941	valid_1's cappa: 0.605513
# [800]	training's rmse: 0.919874	training's cappa: 0.662653	valid_1's rmse: 0.979206	valid_1's cappa: 0.606951
# [900]	training's rmse: 0.912764	training's cappa: 0.66895	valid_1's rmse: 0.978193	valid_1's cappa: 0.607427
# [1000]	training's rmse: 0.906069	training's cappa: 0.67508	valid_1's rmse: 0.978145	valid_1's cappa: 0.607975
# [1100]	training's rmse: 0.899827	training's cappa: 0.679904	valid_1's rmse: 0.977532	valid_1's cappa: 0.609678
# [1200]	training's rmse: 0.894013	training's cappa: 0.68544	valid_1's rmse: 0.977207	valid_1's cappa: 0.609726
# [1300]	training's rmse: 0.888534	training's cappa: 0.691191	valid_1's rmse: 0.97728	valid_1's cappa: 0.607375
# [1400]	training's rmse: 0.883168	training's cappa: 0.694954	valid_1's rmse: 0.977367	valid_1's cappa: 0.609382
# [1500]	training's rmse: 0.878107	training's cappa: 0.700286	valid_1's rmse: 0.977427	valid_1's cappa: 0.609476
# Early stopping, best iteration is:
# [1136]	training's rmse: 0.897678	training's cappa: 0.682341	valid_1's rmse: 0.977371	valid_1's cappa: 0.610599
# parameter 9 77 0.5976327664580293 0.31494347754118374 2 26.688726082129893 36.07552083327886
# score 0.9773714551778184
# |  23       | -0.9774   |  0.5976   |  26.69    |  36.08    |  9.265    |  77.21    |  0.3149   |  2.248    |
# Training until validation scores don't improve for 400 rounds
# [100]	training's rmse: 1.03771	training's cappa: 0.571929	valid_1's rmse: 1.05072	valid_1's cappa: 0.541559
# [200]	training's rmse: 0.967945	training's cappa: 0.639703	valid_1's rmse: 0.998767	valid_1's cappa: 0.595932
# [300]	training's rmse: 0.934062	training's cappa: 0.65737	valid_1's rmse: 0.984004	valid_1's cappa: 0.599533
# [400]	training's rmse: 0.910849	training's cappa: 0.675134	valid_1's rmse: 0.978676	valid_1's cappa: 0.603195
# [500]	training's rmse: 0.892387	training's cappa: 0.689205	valid_1's rmse: 0.976312	valid_1's cappa: 0.602351
# [600]	training's rmse: 0.876676	training's cappa: 0.701114	valid_1's rmse: 0.975439	valid_1's cappa: 0.606109
# [700]	training's rmse: 0.862273	training's cappa: 0.713392	valid_1's rmse: 0.975162	valid_1's cappa: 0.603387
# [800]	training's rmse: 0.849207	training's cappa: 0.724822	valid_1's rmse: 0.975158	valid_1's cappa: 0.60416
# [900]	training's rmse: 0.836934	training's cappa: 0.735001	valid_1's rmse: 0.975183	valid_1's cappa: 0.605291
# [1000]	training's rmse: 0.825504	training's cappa: 0.743941	valid_1's rmse: 0.975765	valid_1's cappa: 0.604426
# ...
#   elif categorical_feature == 'auto':
# /home/jupyter-shliu/.local/lib/python3.6/site-packages/lightgbm/basic.py:1247: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is []
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /home/jupyter-shliu/.local/lib/python3.6/site-packages/lightgbm/basic.py:285: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if categorical_feature == 'auto':  # use cat cols from DataFrame
# Training until validation scores don't improve for 400 rounds
# [100]	training's rmse: 1.07126	training's cappa: 0.473212	valid_1's rmse: 1.08197	valid_1's cappa: 0.439191
# [200]	training's rmse: 0.994839	training's cappa: 0.617249	valid_1's rmse: 1.0181	valid_1's cappa: 0.582095
# [300]	training's rmse: 0.95637	training's cappa: 0.64594	valid_1's rmse: 0.992846	valid_1's cappa: 0.596997
# [400]	training's rmse: 0.932544	training's cappa: 0.659944	valid_1's rmse: 0.982042	valid_1's cappa: 0.603565
# [500]	training's rmse: 0.915569	training's cappa: 0.672221	valid_1's rmse: 0.977607	valid_1's cappa: 0.60662
# [600]	training's rmse: 0.901811	training's cappa: 0.682871	valid_1's rmse: 0.975946	valid_1's cappa: 0.608533
# [700]	training's rmse: 0.89012	training's cappa: 0.691909	valid_1's rmse: 0.974435	valid_1's cappa: 0.609899
# [800]	training's rmse: 0.879641	training's cappa: 0.700987	valid_1's rmse: 0.973784	valid_1's cappa: 0.610082
# [900]	training's rmse: 0.86981	training's cappa: 0.70905	valid_1's rmse: 0.973497	valid_1's cappa: 0.612281
# [1000]	training's rmse: 0.860622	training's cappa: 0.71635	valid_1's rmse: 0.973439	valid_1's cappa: 0.614009
# [1100]	training's rmse: 0.851504	training's cappa: 0.724272	valid_1's rmse: 0.973504	valid_1's cappa: 0.612865
# [1200]	training's rmse: 0.843066	training's cappa: 0.73244	valid_1's rmse: 0.973621	valid_1's cappa: 0.61175
# [1300]	training's rmse: 0.835046	training's cappa: 0.738815	valid_1's rmse: 0.973822	valid_1's cappa: 0.611166
# Early stopping, best iteration is:
# [976]	training's rmse: 0.862743	training's cappa: 0.714207	valid_1's rmse: 0.973319	valid_1's cappa: 0.614385
# parameter 5 53 0.31031842880267807 0.9110174724067721 1 0.767911107833583 7.09316107677816
# score 0.9733193996050885
# |  60       | -0.9733   |  0.3103   |  0.7679   |  7.093    |  5.254    |  53.74    |  0.911    |  1.114    |
# /home/jupyter-shliu/.local/lib/python3.6/site-packages/lightgbm/engine.py:153: UserWarning: Found `early_stopping_rounds` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# /home/jupyter-shliu/.local/lib/python3.6/site-packages/lightgbm/basic.py:1236: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if self.categorical_feature == categorical_feature:
# /home/jupyter-shliu/.local/lib/python3.6/site-packages/lightgbm/basic.py:1242: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   elif categorical_feature == 'auto':
# /home/jupyter-shliu/.local/lib/python3.6/site-packages/lightgbm/basic.py:1247: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is []
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /home/jupyter-shliu/.local/lib/python3.6/site-packages/lightgbm/basic.py:285: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if categorical_feature == 'auto':  # use cat cols from DataFrame
# Training until validation scores don't improve for 400 rounds
# [100]	training's rmse: 1.03863	training's cappa: 0.551876	valid_1's rmse: 1.06506	valid_1's cappa: 0.489084
# [200]	training's rmse: 0.948039	training's cappa: 0.673246	valid_1's rmse: 1.00237	valid_1's cappa: 0.595826
# [300]	training's rmse: 0.90065	training's cappa: 0.697065	valid_1's rmse: 0.982185	valid_1's cappa: 0.608424
# [400]	training's rmse: 0.867908	training's cappa: 0.716114	valid_1's rmse: 0.974315	valid_1's cappa: 0.611402
# [500]	training's rmse: 0.842295	training's cappa: 0.734103	valid_1's rmse: 0.97264	valid_1's cappa: 0.611804
# [600]	training's rmse: 0.819868	training's cappa: 0.74957	valid_1's rmse: 0.972174	valid_1's cappa: 0.612046
# [700]	training's rmse: 0.799457	training's cappa: 0.764281	valid_1's rmse: 0.972561	valid_1's cappa: 0.612506
# [800]	training's rmse: 0.781143	training's cappa: 0.778695	valid_1's rmse: 0.973347	valid_1's cappa: 0.6134
# [900]	training's rmse: 0.763946	training's cappa: 0.792559	valid_1's rmse: 0.974136	valid_1's cappa: 0.613305
# Early stopping, best iteration is:
# [584]	training's rmse: 0.823344	training's cappa: 0.747404	valid_1's rmse: 0.972004	valid_1's cappa: 0.611762
# parameter 15 59 0.40027276241287435 0.8226114143842176 1 0.5000840175953077 34.38490578349007
# score 0.972004094801829
# |  61       | -0.972    |  0.4003   |  0.5001   |  34.38    |  15.89    |  59.75    |  0.8226   |  1.078    |
# /home/jupyter-shliu/.local/lib/python3.6/site-packages/lightgbm/engine.py:153: UserWarning: Found `early_stopping_rounds` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# /home/jupyter-shliu/.local/lib/python3.6/site-packages/lightgbm/basic.py:1236: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if self.categorical_feature == categorical_feature:
# /home/jupyter-shliu/.local/lib/python3.6/site-packages/lightgbm/basic.py:1242: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   elif categorical_feature == 'auto':
# /home/jupyter-shliu/.local/lib/python3.6/site-packages/lightgbm/basic.py:1247: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is []
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /home/jupyter-shliu/.local/lib/python3.6/site-packages/lightgbm/basic.py:285: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if categorical_feature == 'auto':  # use cat cols from DataFrame
# Training until validation scores don't improve for 400 rounds
# [100]	training's rmse: 1.07391	training's cappa: 0.468023	valid_1's rmse: 1.08423	valid_1's cappa: 0.437515
# [200]	training's rmse: 0.997701	training's cappa: 0.613911	valid_1's rmse: 1.02006	valid_1's cappa: 0.576275
# [300]	training's rmse: 0.959281	training's cappa: 0.644134	valid_1's rmse: 0.994198	valid_1's cappa: 0.593411
# [400]	training's rmse: 0.93512	training's cappa: 0.658609	valid_1's rmse: 0.983485	valid_1's cappa: 0.60258
# [500]	training's rmse: 0.918014	training's cappa: 0.670529	valid_1's rmse: 0.978505	valid_1's cappa: 0.605645
# [600]	training's rmse: 0.904304	training's cappa: 0.679799	valid_1's rmse: 0.976255	valid_1's cappa: 0.608202
# [700]	training's rmse: 0.893585	training's cappa: 0.687033	valid_1's rmse: 0.974968	valid_1's cappa: 0.608502
# [800]	training's rmse: 0.883189	training's cappa: 0.695139	valid_1's rmse: 0.97436	valid_1's cappa: 0.609997
# [900]	training's rmse: 0.8733	training's cappa: 0.704699	valid_1's rmse: 0.973945	valid_1's cappa: 0.60987
# [1000]	training's rmse: 0.864768	training's cappa: 0.711487	valid_1's rmse: 0.973732	valid_1's cappa: 0.610851
# [1100]	training's rmse: 0.856824	training's cappa: 0.719309	valid_1's rmse: 0.973882	valid_1's cappa: 0.611811
# [1200]	training's rmse: 0.84951	training's cappa: 0.726233	valid_1's rmse: 0.973905	valid_1's cappa: 0.613998
# [1300]	training's rmse: 0.842664	training's cappa: 0.731497	valid_1's rmse: 0.974056	valid_1's cappa: 0.612002
# Early stopping, best iteration is:
# [960]	training's rmse: 0.867902	training's cappa: 0.708878	valid_1's rmse: 0.973646	valid_1's cappa: 0.611749
# parameter 5 55 0.30665762405017605 0.9995829162176366 1 0.17852035570387717 13.889168899019941
# score 0.973646369391487
# |  62       | -0.9736   |  0.3067   |  0.1785   |  13.89    |  5.014    |  55.39    |  0.9996   |  1.028    |
# /home/jupyter-shliu/.local/lib/python3.6/site-packages/lightgbm/engine.py:153: UserWarning: Found `early_stopping_rounds` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# /home/jupyter-shliu/.local/lib/python3.6/site-packages/lightgbm/basic.py:1236: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if self.categorical_feature == categorical_feature:
# /home/jupyter-shliu/.local/lib/python3.6/site-packages/lightgbm/basic.py:1242: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   elif categorical_feature == 'auto':
# /home/jupyter-shliu/.local/lib/python3.6/site-packages/lightgbm/basic.py:1247: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is []
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /home/jupyter-shliu/.local/lib/python3.6/site-packages/lightgbm/basic.py:285: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if categorical_feature == 'auto':  # use cat cols from DataFrame
# Training until validation scores don't improve for 400 rounds
# [100]	training's rmse: 1.02844	training's cappa: 0.571332	valid_1's rmse: 1.0656	valid_1's cappa: 0.488982
# [200]	training's rmse: 0.927876	training's cappa: 0.696778	valid_1's rmse: 1.00399	valid_1's cappa: 0.595374
# [300]	training's rmse: 0.87084	training's cappa: 0.72691	valid_1's rmse: 0.984086	valid_1's cappa: 0.606298
# [400]	training's rmse: 0.830242	training's cappa: 0.7511	valid_1's rmse: 0.976513	valid_1's cappa: 0.610219
# [500]	training's rmse: 0.797333	training's cappa: 0.77123	valid_1's rmse: 0.974277	valid_1's cappa: 0.611231
# [600]	training's rmse: 0.768647	training's cappa: 0.791064	valid_1's rmse: 0.974317	valid_1's cappa: 0.614249
# [700]	training's rmse: 0.743147	training's cappa: 0.809524	valid_1's rmse: 0.974698	valid_1's cappa: 0.612122
# [800]	training's rmse: 0.720059	training's cappa: 0.823089	valid_1's rmse: 0.975561	valid_1's cappa: 0.607208
# [900]	training's rmse: 0.699449	training's cappa: 0.835703	valid_1's rmse: 0.976454	valid_1's cappa: 0.607571
# Early stopping, best iteration is:
# [584]	training's rmse: 0.772933	training's cappa: 0.787572	valid_1's rmse: 0.974078	valid_1's cappa: 0.614353
# parameter 15 91 0.36875610231747763 0.9285213471389111 2 0.21106692440879238 38.70654074707002
# score 0.9740784008891016
# |  63       | -0.9741   |  0.3688   |  0.2111   |  38.71    |  15.95    |  91.19    |  0.9285   |  2.813    |
# /home/jupyter-shliu/.local/lib/python3.6/site-packages/lightgbm/engine.py:153: UserWarning: Found `early_stopping_rounds` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# /home/jupyter-shliu/.local/lib/python3.6/site-packages/lightgbm/basic.py:1236: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if self.categorical_feature == categorical_feature:
# /home/jupyter-shliu/.local/lib/python3.6/site-packages/lightgbm/basic.py:1242: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   elif categorical_feature == 'auto':
# /home/jupyter-shliu/.local/lib/python3.6/site-packages/lightgbm/basic.py:1247: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is []
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /home/jupyter-shliu/.local/lib/python3.6/site-packages/lightgbm/basic.py:285: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if categorical_feature == 'auto':  # use cat cols from DataFrame
# Training until validation scores don't improve for 400 rounds
# [100]	training's rmse: 1.07845	training's cappa: 0.455833	valid_1's rmse: 1.08584	valid_1's cappa: 0.433385
# [200]	training's rmse: 1.00506	training's cappa: 0.604055	valid_1's rmse: 1.02116	valid_1's cappa: 0.579722
# [300]	training's rmse: 0.970209	training's cappa: 0.632149	valid_1's rmse: 0.995553	valid_1's cappa: 0.596633
# [400]	training's rmse: 0.948781	training's cappa: 0.643877	valid_1's rmse: 0.984166	valid_1's cappa: 0.603522
# [500]	training's rmse: 0.933887	training's cappa: 0.653166	valid_1's rmse: 0.979427	valid_1's cappa: 0.605608
# [600]	training's rmse: 0.921928	training's cappa: 0.663038	valid_1's rmse: 0.976846	valid_1's cappa: 0.609163
# [700]	training's rmse: 0.911739	training's cappa: 0.671594	valid_1's rmse: 0.975733	valid_1's cappa: 0.608902
# [800]	training's rmse: 0.902271	training's cappa: 0.678601	valid_1's rmse: 0.974904	valid_1's cappa: 0.606849
# [900]	training's rmse: 0.893532	training's cappa: 0.686116	valid_1's rmse: 0.974598	valid_1's cappa: 0.610451
# [1000]	training's rmse: 0.885316	training's cappa: 0.69324	valid_1's rmse: 0.97465	valid_1's cappa: 0.611227
# [1100]	training's rmse: 0.877387	training's cappa: 0.699845	valid_1's rmse: 0.974611	valid_1's cappa: 0.611362
# [1200]	training's rmse: 0.870209	training's cappa: 0.705881	valid_1's rmse: 0.974557	valid_1's cappa: 0.611577
# [1300]	training's rmse: 0.863387	training's cappa: 0.713042	valid_1's rmse: 0.974619	valid_1's cappa: 0.612573
# [1400]	training's rmse: 0.856801	training's cappa: 0.717645	valid_1's rmse: 0.97479	valid_1's cappa: 0.611695
# [1500]	training's rmse: 0.850522	training's cappa: 0.723436	valid_1's rmse: 0.974974	valid_1's cappa: 0.609952
# [1600]	training's rmse: 0.844286	training's cappa: 0.728393	valid_1's rmse: 0.975149	valid_1's cappa: 0.609712
# Early stopping, best iteration is:
# [1258]	training's rmse: 0.86603	training's cappa: 0.71039	valid_1's rmse: 0.974486	valid_1's cappa: 0.61307
# parameter 5 24 0.34997464896475433 0.9738442892194086 1 1.3776999010008422 48.3063493444671
# score 0.9744857150391789
# |  64       | -0.9745   |  0.35     |  1.378    |  48.31    |  5.69     |  24.5     |  0.9738   |  1.269    |
# /home/jupyter-shliu/.local/lib/python3.6/site-packages/lightgbm/engine.py:153: UserWarning: Found `early_stopping_rounds` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# /home/jupyter-shliu/.local/lib/python3.6/site-packages/lightgbm/basic.py:1236: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if self.categorical_feature == categorical_feature:
# /home/jupyter-shliu/.local/lib/python3.6/site-packages/lightgbm/basic.py:1242: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   elif categorical_feature == 'auto':
# /home/jupyter-shliu/.local/lib/python3.6/site-packages/lightgbm/basic.py:1247: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is []
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /home/jupyter-shliu/.local/lib/python3.6/site-packages/lightgbm/basic.py:285: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if categorical_feature == 'auto':  # use cat cols from DataFrame
# Training until validation scores don't improve for 400 rounds
# [100]	training's rmse: 1.03586	training's cappa: 0.556119	valid_1's rmse: 1.06996	valid_1's cappa: 0.47844
# [200]	training's rmse: 0.93976	training's cappa: 0.684592	valid_1's rmse: 1.00823	valid_1's cappa: 0.592036

# %% [markdown]
# ## 原理理解
# ## https://github.com/fmfn/BayesianOptimization/blob/master/examples/visualization.ipynb
#
#
# #### init step越多，越不容易卡在local mini
# #### Kappa決定confidence interval範圍
# #### 不了解kappa, GP的過程 唉
